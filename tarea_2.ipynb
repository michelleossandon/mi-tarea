# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score






datos=pd.read_csv("C:/Users/eilee/OneDrive/Escritorio/Michelle/train.csv", header= None)

print(datos.head())
# Out:
#    0           1         2            3        4       5      6         7
# 0  Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 1   1          60        RL           65     8450    Pave    NaN       Reg
# 2   2          20        RL           80     9600    Pave    NaN       Reg
# 3   3          60        RL           68    11250    Pave    NaN       IR1
# 4   4          70        RL           60     9550    Pave    NaN       IR1
#
#             8          9   ...        71      72     73           74       75
# 0  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 1          Lvl     AllPub  ...         0     NaN    NaN          NaN        0
# 2          Lvl     AllPub  ...         0     NaN    NaN          NaN        0
# 3          Lvl     AllPub  ...         0     NaN    NaN          NaN        0
# 4          Lvl     AllPub  ...         0     NaN    NaN          NaN        0
#
# ...

# %% [markdown]
# Importe las librerias y mi base de datos cvs

# %%
print(len(datos))
# Out:
# 1461

# %% [markdown]
# Aqui imprimi el numero de datos de la base, osea la logitud

# %%
raw_data = pd.read_csv("C:/Users/eilee/OneDrive/Escritorio/Michelle/train.csv")

# %% [markdown]
#     Aqui le dije que mi base de datos esta sin modificaciones, leyendo mi base con la libreria pandas

# %%
plt.scatter(x=raw_data["LotArea"], y=raw_data["SalePrice"])

# %% [markdown]
# Aqui imprimi un grafico de dispersión con las variables x e y como cantidad de metros cuadrados como la variable independiente y costo de la casa en dolares como la dependiente, eso quiere decir que ante una variación de los metros cuadrados yo esperaría que haya una variación en el precio

# %%
import matplotlib.pyplot as plt
import pandas as pd


raw_data = pd.read_csv('C:/Users/eilee/OneDrive/Escritorio/Michelle/train.csv')


plt.scatter(x=raw_data["LotArea"], y=raw_data["SalePrice"])


plt.xlim(0, 90000)

plt.show()

# %% [markdown]
# Aqui acorte los ejes x e y hasta 90.000 y 700.000 puesto que creo que no tenia sentido que estuviera con limites tan grandes si casi no habian datos

# %%
raw_data = raw_data.sample(frac=1)

test_data = raw_data.iloc[1400:]
train_data = raw_data.iloc[:1400]

x_train = train_data["LotArea"].values.reshape(-1,1)
y_train = train_data["SalePrice"]

x_test = test_data["LotArea"].values.reshape(-1,1)
y_test = test_data["SalePrice"]

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

print("accuracy: ",r2_score(y_test,y_pred)*100,"%")
# Out:
# accuracy:  13.995134302251056 %

# %% [markdown]
# Con los tres anteriores entrene mi modelo y le saque el coeficiente de determinación

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score


raw_data = pd.read_csv('C:/Users/eilee/OneDrive/Escritorio/Michelle/train.csv')


raw_data = raw_data.sample(frac=1)
test_data = raw_data.iloc[1400:]
train_data = raw_data.iloc[:1400]
x_train = train_data["LotArea"].values.reshape(-1,1)
y_train = train_data["SalePrice"]
x_test = test_data["LotArea"].values.reshape(-1,1)
y_test = test_data["SalePrice"]


model = LinearRegression()
model.fit(x_train, y_train)


y_pred = model.predict(x_test)


r2 = r2_score(y_test, y_pred)


plt.scatter(x=x_test, y=y_test, color="blue")
plt.scatter(x=x_train, y=y_train, color="green")
plt.plot(x_test, model.predict(x_test), color="red")


plt.xlabel('LotArea')
plt.ylabel('SalePrice')
plt.title('Regresión lineal: LotArea vs. SalePrice\nR² = {:.2f}'.format(r2))


plt.xlim(0, 90000)
plt.ylim(0,700000)


print(f"Correlación: {corr:.2f}")
print(f"Intercepto: {intercept:.2f}")
print(f"Función de la regresión lineal: y = {slope:.2f}x + {intercept:.2f}")



plt.show()
# Out:
# Correlación: 0.37
# Intercepto: 153131.65
# Función de la regresión lineal: y = 1.20x + 153131.65

# %% [markdown]
# Luego hice una regresión lineal con un grafico con los limites de x e y establecidos,con los nombres en los ejes, el titulo del grafico y el coeficiente de determinación impreso arriba, ademas obtuve el dato de intercepto y la funsión de la regresión
